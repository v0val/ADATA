# %% [markdown]
# ## Условие 1:

# %% [markdown]
# #### Задача 1
# Скачать данные по ссылке https://www.kaggle.com/datasets/ionaskel/laptop-prices
# Считать данные с помощью pandas
# Вывести на экран первые 5 строк

# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\olen\\Downloads\\_КУРС_GB_Разработчик\\11 Анализ данных\\dz\\kc_house_data.csv', encoding='cp1251')
df.head(5)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %% [markdown]
# 1.2 Создать новый признак delta_renovated, который будет содержать разницу в годах между годом реновацией дома и годом постройки дома.Если реновации дома не было, то в новом признаке поставьте 0

# %%
df['delta_renovated'] = 0
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  sqft_above  \
# 0             1180      5650     1.0           0     0  ...        1180
# ...

# %%
df.loc[df['yr_renovated']!=0, 'delta_renovated'] = df['yr_renovated'] - df['yr_built']
df.head(50)
# Out:
#             id             date      price  bedrooms  bathrooms  sqft_living  \
# 0   7129300520  20141013T000000   221900.0         3       1.00         1180
# 1   6414100192  20141209T000000   538000.0         3       2.25         2570
# 2   5631500400  20150225T000000   180000.0         2       1.00          770
# 3   2487200875  20141209T000000   604000.0         4       3.00         1960
# 4   1954400510  20150218T000000   510000.0         3       2.00         1680
# 5   7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6   1321400060  20140627T000000   257500.0         3       2.25         1715
# 7   2008000270  20150115T000000   291850.0         3       1.50         1060
# 8   2414600126  20150415T000000   229500.0         3       1.00         1780
# 9   3793500160  20150312T000000   323000.0         3       2.50         1890
# 10  1736800520  20150403T000000   662500.0         3       2.50         3560
# ...

# %% [markdown]
# 1.3 Создайте признаки года продажи, месяца продажи

# %%
df['yr_sale']=0

# %%
df['mth_sale']=0
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  yr_built  \
# 0             1180      5650     1.0           0     0  ...      1955
# ...

# %% [markdown]
# 1.4 Удалите признаки date, zipcode, lat, long

# %%
df = df.drop(columns=['date','zipcode','lat','long'])
df
# Out:
#                id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      7129300520  221900.0         3       1.00         1180      5650
# 1      6414100192  538000.0         3       2.25         2570      7242
# 2      5631500400  180000.0         2       1.00          770     10000
# 3      2487200875  604000.0         4       3.00         1960      5000
# 4      1954400510  510000.0         3       2.00         1680      8080
# ...           ...       ...       ...        ...          ...       ...
# 21608   263000018  360000.0         3       2.50         1530      1131
# 21609  6600060120  400000.0         4       2.50         2310      5813
# 21610  1523300141  402101.0         2       0.75         1020      1350
# 21611   291310100  400000.0         3       2.50         1600      2388
# 21612  1523300157  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %% [markdown]
# ### Условие 2:

# %% [markdown]
# #### 2 задача
# Создайте датафрейм с клиентами:clients = pd.DataFrame({
# 'client_id': [1459, 4684, 3498, 3942, 4535, 2308, 2866, 2765, 1472, 4236, 2295,
# 939, 3840, 280, 20, 4332, 3475, 4213, 3113, 4809, 2134, 2242,
# 2068, 4929, 1384, 1589, 3317, 2260, 1727, 1764, 1611, 1474],
# 'house_id': [8965450190, 6823100225, 5104540330, 2131701075, 1522700060,
# 1189000207, 6821600300, 7137950720, 9510920050, 6131600255,
# 5428000070, 1788800910, 8100400160, 3123049142, 6306800010,
# 5083000375, 7920100025, 1951600150, 809001400, 339600110,
# 1622049154, 1099600250, 8563000110, 2768100205, 3995700435,
# 8861700030, 3303980210, 7731100066, 8146100580, 825069097,
# 3889100029, 9524100196]
# })

# %%
clients = pd.DataFrame({ 'client_id': [1459, 4684, 3498, 3942, 4535, 2308, 2866, 2765, 1472, 4236, 2295, 939, 
                                       3840, 280, 20, 4332, 3475, 4213, 3113, 4809, 2134, 2242, 2068, 4929, 
                                       1384, 1589, 3317, 2260, 1727, 1764, 1611, 1474], 
                        'house_id': [8965450190, 6823100225, 5104540330, 2131701075, 1522700060, 1189000207, 
                                     6821600300, 7137950720, 9510920050, 6131600255, 5428000070, 1788800910, 
                                     8100400160, 3123049142, 6306800010, 5083000375, 7920100025, 1951600150, 
                                     809001400, 339600110, 1622049154, 1099600250, 8563000110, 2768100205, 
                                     3995700435, 8861700030, 3303980210, 7731100066, 8146100580, 825069097, 
                                     3889100029, 9524100196] 
                       })

# %%
clients
# Out:
#     client_id    house_id
# 0        1459  8965450190
# 1        4684  6823100225
# 2        3498  5104540330
# 3        3942  2131701075
# 4        4535  1522700060
# 5        2308  1189000207
# 6        2866  6821600300
# 7        2765  7137950720
# 8        1472  9510920050
# 9        4236  6131600255
# 10       2295  5428000070
# 11        939  1788800910
# 12       3840  8100400160
# 13        280  3123049142
# 14         20  6306800010
# 15       4332  5083000375
# 16       3475  7920100025
# 17       4213  1951600150
# 18       3113   809001400
# 19       4809   339600110
# 20       2134  1622049154
# 21       2242  1099600250
# 22       2068  8563000110
# 23       4929  2768100205
# 24       1384  3995700435
# 25       1589  8861700030
# 26       3317  3303980210
# 27       2260  7731100066
# 28       1727  8146100580
# 29       1764   825069097
# 30       1611  3889100029
# 31       1474  9524100196

# %% [markdown]
# 2.1 Присоедините к таблице clients данные по домам через метод join

# %%
clients.set_index('house_id', inplace = True)

# %%
clients
# Out:
#             client_id
# house_id
# 8965450190       1459
# 6823100225       4684
# 5104540330       3498
# 2131701075       3942
# 1522700060       4535
# 1189000207       2308
# 6821600300       2866
# 7137950720       2765
# 9510920050       1472
# 6131600255       4236
# 5428000070       2295
# 1788800910        939
# 8100400160       3840
# 3123049142        280
# 6306800010         20
# 5083000375       4332
# 7920100025       3475
# 1951600150       4213
# 809001400        3113
# 339600110        4809
# 1622049154       2134
# 1099600250       2242
# 8563000110       2068
# 2768100205       4929
# 3995700435       1384
# 8861700030       1589
# 3303980210       3317
# 7731100066       2260
# 8146100580       1727
# 825069097        1764
# 3889100029       1611
# 9524100196       1474

# %%
new = clients.join(df)
new
# Out:
#             client_id  id  price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# house_id
# 8965450190       1459 NaN    NaN       NaN        NaN          NaN       NaN
# 6823100225       4684 NaN    NaN       NaN        NaN          NaN       NaN
# 5104540330       3498 NaN    NaN       NaN        NaN          NaN       NaN
# 2131701075       3942 NaN    NaN       NaN        NaN          NaN       NaN
# 1522700060       4535 NaN    NaN       NaN        NaN          NaN       NaN
# 1189000207       2308 NaN    NaN       NaN        NaN          NaN       NaN
# 6821600300       2866 NaN    NaN       NaN        NaN          NaN       NaN
# 7137950720       2765 NaN    NaN       NaN        NaN          NaN       NaN
# 9510920050       1472 NaN    NaN       NaN        NaN          NaN       NaN
# 6131600255       4236 NaN    NaN       NaN        NaN          NaN       NaN
# 5428000070       2295 NaN    NaN       NaN        NaN          NaN       NaN
# ...

# %% [markdown]
# 2.2 Присоедините к таблице clients данные по домам через метод merge
# Это нужно, чтобы понимать, какие дома покупались клиентами
# house_id - это индексы датафрейма с домами

# %%
#????????????????????????

# %%
df.reset_index(inplace=True)

# %%
clients.reset_index(inplace=True)

# %% [markdown]
# ### не понял в чем ошибка

# %%
new1 = clients.merge(df, left_on='house_id', right_on='id')
new1
# Out:
#       house_id  client_id  index          id      price  bedrooms  bathrooms  \
# 0   8965450190       1459   7314  8965450190   295000.0         3       2.50
# 1   6823100225       4684  15505  6823100225   700000.0         4       1.75
# 2   5104540330       3498   7560  5104540330   679000.0         4       2.50
# 3   2131701075       3942  13185  2131701075   420000.0         3       1.75
# 4   1522700060       4535  10395  1522700060   518000.0         4       2.75
# 5   1189000207       2308   7861  1189000207   387000.0         2       2.50
# 6   6821600300       2866   4660  6821600300   886000.0         3       2.25
# 7   7137950720       2765  13827  7137950720   339100.0         4       2.50
# 8   9510920050       1472  16528  9510920050   725000.0         3       2.50
# 9   6131600255       4236  16228  6131600255   202500.0         3       2.00
# 10  5428000070       2295  20765  5428000070   770000.0         5       3.50
# ...

# %% [markdown]
# ### Условие 3:

# %% [markdown]
# 3 задача
# Составьте несколько сводных таблиц
# 3.1 Найдите среднюю стоимость домов в зависимости от количества спален
# Отсортируйте от меньшей стоимости к большей
# 3.2 Найдите минимальную, среднюю и максимальную стоимости домов в зависимости от состояния дома
# 3.3 Постройте таблицу с подсчетом количества домов в данных в зависимости от вида на набережную и оценкой вида
# 3.4 Каких домов в зависимости от этажности и количества спален больше?
# 3.5 Постройте таблицу с подсчетом медианной стоимости домов в данных в зависимости от состояния дома и оценки дома

# %% [markdown]
# 3.1 Найдите среднюю стоимость домов в зависимости от количества спален
# Отсортируйте от меньшей стоимости к большей

# %%
df.groupby('bedrooms').agg({'price':['mean']}).sort_values(('price', 'mean'))
# Out:
#                  price
#                   mean
# bedrooms
# 1         3.176429e+05
# 2         4.013727e+05
# 0         4.095038e+05
# 3         4.662321e+05
# 11        5.200000e+05
# 4         6.354195e+05
# 33        6.400000e+05
# 5         7.865998e+05
# 10        8.193333e+05
# 6         8.255206e+05
# 9         8.939998e+05
# 7         9.511847e+05
# 8         1.105077e+06

# %% [markdown]
# 3.2 Найдите минимальную, среднюю и максимальную стоимости домов в зависимости от состояния дома

# %%
df.groupby('condition').agg({'price':['min','mean','max']})
# Out:
#               price
#                 min           mean        max
# condition
# 1           78000.0  334431.666667  1500000.0
# 2           80000.0  327287.145349  2555000.0
# 3           75000.0  542012.578148  7062500.0
# 4           89000.0  521200.390033  7700000.0
# 5          110000.0  612418.089359  3650000.0

# %% [markdown]
# 3.3 Постройте таблицу с подсчетом количества домов в данных в зависимости от вида на набережную и оценкой вида

# %%
df.groupby(['waterfront','view']).agg({'price':'count'})
# Out:
#                  price
# waterfront view
# 0          0     19489
#            1       331
#            2       955
#            3       491
#            4       184
# 1          1         1
#            2         8
#            3        19
#            4       135

# %% [markdown]
# 3.4 Каких домов в зависимости от этажности и количества спален больше?

# %%
df.groupby(['floors','bedrooms']).agg({'price':'count'})
# Out:
#                  price
# floors bedrooms
# 1.0    0             4
#        1           162
#        2          1951
#        3          5455
#        4          2383
#        5           605
#        6           104
#        7             9
#        8             5
#        10            1
#        33            1
# 1.5    1            21
#        2           182
#        3           786
#        4           698
#        5           185
#        6            30
#        7             7
#        8             1
# 2.0    0             6
#        1            12
#        2           497
#        3          3118
#        4          3682
#        5           775
#        6           119
#        7            19
#        8             6
#        9             4
#        10            2
#        11            1
# 2.5    1             1
#        2             5
#        3            56
#        4            58
#        5            23
#        6            14
#        7             2
# ...

# %% [markdown]
# 3.5 Постройте таблицу с подсчетом медианной стоимости домов в данных в зависимости от состояния дома и оценки дома

# %%
df.groupby(['condition','grade']).agg({'price':'median'})
# Out:
#                      price
# condition grade
# 1         1       142000.0
#           4       150000.0
#           5       190000.0
#           6       255000.0
#           7       403500.0
#           8       932500.0
# 2         3       280000.0
#           4       145000.0
#           5       180000.0
#           6       235000.0
#           7       305000.0
#           8       429000.0
#           9       715000.0
#           10     1752500.0
# 3         3        75000.0
#           4       205000.0
#           5       234475.0
#           6       265000.0
#           7       357500.0
#           8       485000.0
#           9       689000.0
#           10      890000.0
#           11     1209500.0
#           12     1807500.0
#           13     2888000.0
# 4         4       238525.0
#           5       229975.0
#           6       295000.0
#           7       390000.0
#           8       571250.0
#           9       823500.0
#           10     1030000.0
# ...
